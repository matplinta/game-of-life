# %% [markdown]
# Game defined as :
#
#     *State:
#         - Grid size
#         - Positions of living cells
#     *Rules: eg
#         - A cell survives if it has 2 or 3 neighbours -> dies if 1 or 0 neighbours
#         - Dies if it has more than 3 neighbours.
#         - If a dead cell has 3 neighbours it becomes alive.
#     *Stop test:
#         - If current state = previous state

# %%
# %matplotlib inline
import IPython.display
from io import BytesIO as bio
import PIL.Image
import numpy as np
from abc import ABC, abstractmethod
from copy import copy
import matplotlib.pyplot as plt
import matplotlib
import time
# matplotlib.use('GTK3Agg')

# %%
class State(ABC):
    @abstractmethod
    def copy(self):
        pass

    @abstractmethod
    def apply_rules(self, rules, max_size):
        pass

    @abstractmethod
    def equals(self, other):
        pass

    @abstractmethod
    def get_neighbours(self, elem, max_size):
        pass


class DenseNumpyState(State):
    def __init__(self, grid):
        self.grid = grid

    def copy(self):
        return DenseNumpyState(np.copy(self.grid))

    def equals(self, other):
        if other is None:
            return False
        return np.array_equal(self.grid, other.grid)

    def apply_rules(self, rules, max_size,):
        self.grid = rules.apply_rules(self.grid, max_size, self.get_neighbours)
        return self

    def get_neighbours(self, elem, max_size):
        l = []
        if elem[0]-1 >= 0:
            l.append((elem[0]-1, elem[1]))
        if elem[0]-1 >= 0 and elem[1]-1 >= 0:
            l.append((elem[0]-1, elem[1]-1))
        if elem[0]-1 >= 0 and elem[1]+1 < max_size:
            l.append((elem[0]-1, elem[1]+1))
        if elem[1]-1 >= 0:
            l.append((elem[0], elem[1]-1))
        if elem[1]-1 >= 0 and elem[0]+1 < max_size:
            l.append((elem[0]+1, elem[1]-1))
        if elem[1]+1 < max_size:
            l.append((elem[0], elem[1]+1))
        if elem[0]+1 < max_size:
            l.append((elem[0]+1, elem[1]))
        if elem[1]+1 < max_size and elem[0]+1 < max_size:
            l.append((elem[0]+1, elem[1]+1))
        return l


class SparseSetState(State):
    def __init__(self, grid):
        self.grid = grid

    def copy(self):
        return SparseSetState(copy(self.grid))

    def get_neighbours(self, elem, max_size):
        # Returns the neighbours of a live cell if they lie within the bounds of the grid specified by max_size
        l = []
        if elem[0]-1 >= 0:
            l.append((elem[0]-1, elem[1]))
        if elem[0]-1 >= 0 and elem[1]-1 >= 0:
            l.append((elem[0]-1, elem[1]-1))
        if elem[0]-1 >= 0 and elem[1]+1 < max_size:
            l.append((elem[0]-1, elem[1]+1))
        if elem[1]-1 >= 0:
            l.append((elem[0], elem[1]-1))
        if elem[1]-1 >= 0 and elem[0]+1 < max_size:
            l.append((elem[0]+1, elem[1]-1))
        if elem[1]+1 < max_size:
            l.append((elem[0], elem[1]+1))
        if elem[0]+1 < max_size:
            l.append((elem[0]+1, elem[1]))
        if elem[1]+1 < max_size and elem[0]+1 < max_size:
            l.append((elem[0]+1, elem[1]+1))
        return l

    def equals(self, other):
        if other is None:
            return False
        return self.grid == other.grid

    def apply_rules(self, rules, max_size):
        # Calls the actual rules and provides them with the grid and the neighbour function
        self.grid = rules.apply_rules(self.grid, max_size, self.get_neighbours)
        return self

# %%pixie_debugger
class Rule(ABC):
    @abstractmethod
    def apply_rules(self, grid, max_size, get_neighbours):
        pass


class DenseNumpyRules(Rule):
    def apply_rules(self, grid, max_size, get_neighbours):
        #copied_state = state.copy()
        #grid = state.grid

        grid_ret = copy(grid)
        for i in range(grid.shape[0]):
            for j in range(grid.shape[1]):
                nb = get_neighbours((i, j), max_size)
                counter = 0
                for n in nb:
                    if grid[n] == True:
                        counter += 1
                if (counter < 2 or counter > 3):
                    grid_ret[i][j] = False
                if (counter == 3):
                    grid_ret[i][j] = True
        return grid_ret


class SparseSetRules(Rule):
    def apply_rules(self, grid, max_size, get_neighbours):
        #grid = state.grid
        counter = {}
        for elem in grid:
            if elem not in counter:
                counter[elem] = 0
            nb = get_neighbours(elem, max_size)
            for n in nb:
                if n not in counter:
                    counter[n] = 1
                else:
                    counter[n] += 1
        for c in counter:
            if (counter[c] < 2 or counter[c] > 3):
                grid.discard(c)
            if counter[c] == 3:
                grid.add(c)
        return grid

class Game:
    def __init__(self, initial_state, rules,max_size):
        self.initial_state = initial_state
        self.rules = rules
        self.max_size = max_size
    def run_game(self, it):
        state = self.initial_state
        previous_state = None
        progression = []
        i = 0
        while (not state.equals(previous_state) and i < it):
            i += 1
            previous_state = state.copy()
            progression.append(previous_state.grid)
            state = state.apply_rules(self.rules,self.max_size)
        progression.append(state.grid)
        return progression

def random_grid(size):
    randoms = np.random.randint(2, size=size*size)
    board = set()
    for index, elem in enumerate(randoms):
        if elem == 1:
            x = index%size
            y = int(index/size)
            board.add((x, y))
    return board

# %%
#transform array to a gif and save to a file
def save_gif(array,file_name):
    array = np.uint8(np.clip(array,0,1)*255.0)
    frames = []
    for frame in range(array.shape[0]):
        img = PIL.Image.fromarray(array[frame])
        img = img.resize((500, 500))
        frames.append(img)
    img.save(file_name, save_all=True, duration=33.33, append_images=frames, loop=0,size=(500,500))

# %%
#transform array to a gif and save to a file
def save_img(array, file_name):
    array = np.uint8(np.clip(array,0,1)*255.0)
    print(array.shape[0])
    img = PIL.Image.fromarray(array[array.shape[0] - 1 ])
    img = img.resize((500, 500))
    img.save(file_name, size=(500,500))

# %%
MAX_ITER = 1000
MAX_SIZE = 20
GIF_FOLDER = "gif/"
IMG_FOLDER = "img/"

def generate(number):
    number = str(number)
    init = np.zeros((MAX_SIZE, MAX_SIZE), dtype=bool)
    board = random_grid(MAX_SIZE)

    rules2 = SparseSetRules()
    game = Game(SparseSetState(board), rules2,MAX_SIZE)
    t = time.time()
    rw = game.run_game(MAX_ITER)
    print("Iterations passed: {}, time: {}".format(len(rw), time.time()-t))

    #transform sparse representation to array for plotting
    res = np.zeros((len(rw), MAX_SIZE, MAX_SIZE), dtype=bool)
    for l in range(0,len(rw)):
        for key in rw[l]:
            res[l,key[0], key[1]] = True 

    save_img(res,IMG_FOLDER + number + ".png")
    save_gif(res,GIF_FOLDER + number + ".gif")

# %%
for i in range(102,1001):
    generate(i)
# Out:
# Iterations passed: 1001, time: 0.12668514251708984
# 1001
# Iterations passed: 83, time: 0.023953914642333984
# 83
# Iterations passed: 1001, time: 0.07863521575927734
# 1001
# Iterations passed: 65, time: 0.016825437545776367
# 65
# Iterations passed: 1001, time: 0.09569525718688965
# 1001
# Iterations passed: 151, time: 0.029912233352661133
# 151
# Iterations passed: 53, time: 0.01714015007019043
# 53
# Iterations passed: 179, time: 0.03589057922363281
# 179
# Iterations passed: 143, time: 0.035062551498413086
# 143
# Iterations passed: 1001, time: 0.13235902786254883
# 1001
# Iterations passed: 1001, time: 0.062079668045043945
# 1001
# Iterations passed: 58, time: 0.019895553588867188
# 58
# Iterations passed: 148, time: 0.033933401107788086
# 148
# Iterations passed: 136, time: 0.03913593292236328
# 136
# Iterations passed: 225, time: 0.06991958618164062
# 225
# Iterations passed: 1001, time: 0.14482951164245605
# 1001
# Iterations passed: 49, time: 0.011309385299682617
# 49
# Iterations passed: 63, time: 0.016433000564575195
# 63
# Iterations passed: 1001, time: 0.11170339584350586
# 1001
# Iterations passed: 322, time: 0.06675338745117188
# 322
# Iterations passed: 179, time: 0.032654523849487305
# 179
# Iterations passed: 30, time: 0.009302616119384766
# 30
# Iterations passed: 232, time: 0.058687448501586914
# 232
# Iterations passed: 218, time: 0.06076788902282715
# 218
# Iterations passed: 42, time: 0.012110233306884766
# 42
# Iterations passed: 1001, time: 0.11442184448242188
# 1001
# Iterations passed: 38, time: 0.02039170265197754
# 38
# Iterations passed: 1001, time: 0.1808934211730957
# 1001
# Iterations passed: 1001, time: 0.1098337173461914
# 1001
# Iterations passed: 145, time: 0.0323941707611084
# 145
# Iterations passed: 336, time: 0.23942852020263672
# 336
# Iterations passed: 128, time: 0.02465081214904785
# 128
# Iterations passed: 53, time: 0.01588582992553711
# 53
# Iterations passed: 1001, time: 0.0782620906829834
# 1001
# Iterations passed: 76, time: 0.01653146743774414
# 76
# Iterations passed: 1001, time: 0.10843992233276367
# 1001
# Iterations passed: 41, time: 0.018418312072753906
# 41
# Iterations passed: 82, time: 0.02787470817565918
# 82
# Iterations passed: 1001, time: 0.15879154205322266
# 1001
# Iterations passed: 141, time: 0.04240274429321289
# 141
# Iterations passed: 98, time: 0.02583456039428711
# 98
# Iterations passed: 1001, time: 0.09654974937438965
# 1001
# Iterations passed: 43, time: 0.011731386184692383
# 43
# Iterations passed: 323, time: 0.07869887351989746
# 323
# Iterations passed: 105, time: 0.03479933738708496
# 105
# Iterations passed: 1001, time: 0.0596461296081543
# 1001
# Iterations passed: 145, time: 0.02656865119934082
# 145
# Iterations passed: 1001, time: 0.13495159149169922
# 1001
# Iterations passed: 1001, time: 0.0946037769317627
# 1001
# Iterations passed: 87, time: 0.02577829360961914
# 87
# Iterations passed: 55, time: 0.013642549514770508
# 55
# Iterations passed: 1001, time: 0.09804201126098633
# 1001
# Iterations passed: 139, time: 0.031117916107177734
# 139
# Iterations passed: 169, time: 0.04118800163269043
# 169
# Iterations passed: 1001, time: 0.10004043579101562
# 1001
# Iterations passed: 1001, time: 0.20183491706848145
# 1001
# Iterations passed: 1001, time: 0.08912324905395508
# 1001
# Iterations passed: 87, time: 0.023244619369506836
# 87
# Iterations passed: 1001, time: 0.07763171195983887
# 1001
# Iterations passed: 1001, time: 0.16323280334472656
# 1001
# Iterations passed: 127, time: 0.030970096588134766
# 127
# Iterations passed: 1001, time: 0.14573407173156738
# 1001
# Iterations passed: 511, time: 0.1339712142944336
# 511
# Iterations passed: 1001, time: 0.10979700088500977
# 1001
# Iterations passed: 1001, time: 0.10078215599060059
# 1001
# Iterations passed: 1001, time: 0.17163634300231934
# 1001
# Iterations passed: 1001, time: 0.12145328521728516
# 1001
# Iterations passed: 90, time: 0.024316072463989258
# 90
# Iterations passed: 1001, time: 0.11571621894836426
# 1001
# Iterations passed: 90, time: 0.12237048149108887
# 90
# Iterations passed: 1001, time: 0.39025235176086426
# 1001
# Iterations passed: 1001, time: 0.08527159690856934
# 1001
# Iterations passed: 1001, time: 0.2649867534637451
# 1001
# Iterations passed: 94, time: 0.021198749542236328
# 94
# Iterations passed: 1001, time: 0.14058256149291992
# 1001
# Iterations passed: 87, time: 0.03307223320007324
# 87
# Iterations passed: 46, time: 0.015315771102905273
# 46
# Iterations passed: 67, time: 0.03154921531677246
# 67
# Iterations passed: 152, time: 0.03587508201599121
# 152
# Iterations passed: 1001, time: 0.19094276428222656
# 1001
# Iterations passed: 1001, time: 0.19305062294006348
# 1001
# Iterations passed: 1001, time: 0.09896302223205566
# 1001
# Iterations passed: 1001, time: 0.12823987007141113
# 1001
# Iterations passed: 47, time: 0.01792001724243164
# 47
# Iterations passed: 1001, time: 0.19707632064819336
# 1001
# Iterations passed: 1001, time: 0.18175745010375977
# 1001
# Iterations passed: 1001, time: 0.13492798805236816
# 1001
# Iterations passed: 1001, time: 0.4263451099395752
# 1001
# Iterations passed: 1001, time: 0.3306448459625244
# 1001
# Iterations passed: 1001, time: 0.15653491020202637
# 1001
# Iterations passed: 1001, time: 0.06994938850402832
# 1001
# Iterations passed: 1001, time: 0.06335568428039551
# 1001
# Iterations passed: 1001, time: 0.08103680610656738
# 1001
# Iterations passed: 1001, time: 0.15333843231201172
# 1001
# Iterations passed: 1001, time: 0.1852426528930664
# 1001
# Iterations passed: 48, time: 0.025284767150878906
# 48
# Iterations passed: 59, time: 0.020298242568969727
# 59
# Iterations passed: 1001, time: 0.06176471710205078
# 1001
# Iterations passed: 110, time: 0.021425485610961914
# 110
# Iterations passed: 1001, time: 0.09971737861633301
# 1001
# Iterations passed: 121, time: 0.027442455291748047
# 121
# Iterations passed: 1001, time: 0.18869996070861816
# 1001
# Iterations passed: 1001, time: 0.1416773796081543
# 1001
# Iterations passed: 1001, time: 0.20266437530517578
# 1001
# Iterations passed: 97, time: 0.026223421096801758
# 97
# Iterations passed: 1001, time: 0.16581249237060547
# 1001
# Iterations passed: 50, time: 0.014422416687011719
# 50
# Iterations passed: 158, time: 0.04063844680786133
# 158
# Iterations passed: 91, time: 0.0238189697265625
# 91
# Iterations passed: 1001, time: 0.05564069747924805
# 1001
# Iterations passed: 145, time: 0.028899669647216797
# 145
# Iterations passed: 85, time: 0.03616738319396973
# 85
# Iterations passed: 196, time: 0.049364566802978516
# 196
# Iterations passed: 1001, time: 0.12001347541809082
# 1001
# Iterations passed: 49, time: 0.01871943473815918
# 49
# Iterations passed: 1001, time: 0.11669349670410156
# 1001
# Iterations passed: 210, time: 0.03636789321899414
# 210
# Iterations passed: 1001, time: 0.05728459358215332
# 1001
# Iterations passed: 217, time: 0.0813896656036377
# 217
# Iterations passed: 103, time: 0.021448612213134766
# 103
# Iterations passed: 1001, time: 0.10762310028076172
# 1001
# Iterations passed: 55, time: 0.013564825057983398
# 55
# Iterations passed: 1001, time: 0.17544221878051758
# 1001
# Iterations passed: 131, time: 0.027543067932128906
# 131
# Iterations passed: 32, time: 0.008202791213989258
# 32
# Iterations passed: 1001, time: 0.08694028854370117
# 1001
# Iterations passed: 1001, time: 0.1139378547668457
# 1001
# Iterations passed: 173, time: 0.04647326469421387
# 173
# Iterations passed: 1001, time: 0.0654146671295166
# 1001
# Iterations passed: 185, time: 0.04149293899536133
# 185
# Iterations passed: 173, time: 0.03978919982910156
# 173
# Iterations passed: 94, time: 0.0266263484954834
# 94
# Iterations passed: 147, time: 0.0287778377532959
# 147
# Iterations passed: 69, time: 0.02041006088256836
# 69
# Iterations passed: 354, time: 0.08246564865112305
# 354
# Iterations passed: 263, time: 0.048276424407958984
# 263
# Iterations passed: 70, time: 0.02681565284729004
# 70
# Iterations passed: 1001, time: 0.08867120742797852
# 1001
# Iterations passed: 1001, time: 0.09513258934020996
# 1001
# Iterations passed: 163, time: 0.039389848709106445
# 163
# Iterations passed: 135, time: 0.029442787170410156
# 135
# Iterations passed: 1001, time: 0.11995196342468262
# 1001
# Iterations passed: 86, time: 0.01838827133178711
# 86
# Iterations passed: 1001, time: 0.10124564170837402
# 1001
# Iterations passed: 1001, time: 0.07351803779602051
# 1001
# Iterations passed: 97, time: 0.033586978912353516
# 97
# Iterations passed: 90, time: 0.01979684829711914
# 90
# Iterations passed: 1001, time: 0.10687518119812012
# 1001
# Iterations passed: 36, time: 0.011743783950805664
# 36
# Iterations passed: 112, time: 0.029973745346069336
# 112
# Iterations passed: 1001, time: 0.20441269874572754
# 1001
# Iterations passed: 102, time: 0.04206228256225586
# 102
# Iterations passed: 59, time: 0.013431072235107422
# 59
# Iterations passed: 113, time: 0.035530805587768555
# 113
# Iterations passed: 1001, time: 0.17875242233276367
# 1001
# Iterations passed: 106, time: 0.02605581283569336
# 106
# Iterations passed: 1001, time: 0.0982048511505127
# 1001
# Iterations passed: 1001, time: 0.0562283992767334
# 1001
# Iterations passed: 1001, time: 0.24233078956604004
# 1001
# Iterations passed: 428, time: 0.24491524696350098
# 428
# Iterations passed: 59, time: 0.03052210807800293
# 59
# Iterations passed: 192, time: 0.060575008392333984
# 192
# Iterations passed: 213, time: 0.04984641075134277
# 213
# Iterations passed: 67, time: 0.009611368179321289
# 67
# Iterations passed: 1001, time: 0.1267540454864502
# 1001
# Iterations passed: 1001, time: 0.15189790725708008
# 1001
# Iterations passed: 1001, time: 0.2960789203643799
# 1001
# Iterations passed: 1001, time: 0.1836717128753662
# 1001
# Iterations passed: 1001, time: 0.15403008460998535
# 1001
# Iterations passed: 48, time: 0.04123854637145996
# 48
# Iterations passed: 1001, time: 0.18992948532104492
# 1001
# Iterations passed: 87, time: 0.02633523941040039
# 87
# Iterations passed: 1001, time: 0.21262478828430176
# 1001
# Iterations passed: 179, time: 0.04872918128967285
# 179
# Iterations passed: 1001, time: 0.2051689624786377
# 1001
# Iterations passed: 1001, time: 0.1653897762298584
# 1001
# Iterations passed: 1001, time: 0.20241737365722656
# 1001
# Iterations passed: 65, time: 0.015400171279907227
# 65
# Iterations passed: 244, time: 0.07788610458374023
# 244
# Iterations passed: 1001, time: 0.15409588813781738
# 1001
# Iterations passed: 1001, time: 0.1785881519317627
# 1001
# Iterations passed: 1001, time: 0.08184552192687988
# 1001
# Iterations passed: 1001, time: 0.14888501167297363
# 1001
# Iterations passed: 1001, time: 0.14102888107299805
# 1001
# Iterations passed: 38, time: 0.016371965408325195
# 38
# Iterations passed: 1001, time: 0.09392476081848145
# 1001
# Iterations passed: 1001, time: 0.10524678230285645
# 1001
# Iterations passed: 162, time: 0.0479280948638916
# 162
# Iterations passed: 80, time: 0.01984572410583496
# 80
# Iterations passed: 55, time: 0.015003442764282227
# 55
# Iterations passed: 314, time: 0.152693510055542
# 314
# Iterations passed: 335, time: 0.08376550674438477
# 335
# Iterations passed: 64, time: 0.01871967315673828
# 64
# Iterations passed: 1001, time: 0.09933733940124512
# 1001
# Iterations passed: 1001, time: 0.05773162841796875
# 1001
# Iterations passed: 1001, time: 0.16735196113586426
# 1001
# Iterations passed: 215, time: 0.05274200439453125
# 215
# Iterations passed: 1001, time: 0.1427769660949707
# 1001
# Iterations passed: 231, time: 0.07551932334899902
# 231
# Iterations passed: 244, time: 0.0674746036529541
# 244
# Iterations passed: 44, time: 0.008938312530517578
# 44
# Iterations passed: 1001, time: 0.16141748428344727
# 1001
# Iterations passed: 1001, time: 0.24875998497009277
# 1001
# Iterations passed: 89, time: 0.04673266410827637
# 89
# Iterations passed: 40, time: 0.034810543060302734
# 40
# Iterations passed: 1001, time: 0.49296998977661133
# 1001
# Iterations passed: 1001, time: 0.11989045143127441
# 1001
# Iterations passed: 1001, time: 0.07234001159667969
# 1001
# Iterations passed: 101, time: 0.032154083251953125
# 101
# Iterations passed: 83, time: 0.017688512802124023
# 83
# Iterations passed: 1001, time: 0.17415833473205566
# 1001
# Iterations passed: 50, time: 0.01519465446472168
# 50
# Iterations passed: 66, time: 0.02147841453552246
# 66
# Iterations passed: 110, time: 0.03163719177246094
# 110
# Iterations passed: 1001, time: 0.1560227870941162
# 1001
# Iterations passed: 1001, time: 0.13728094100952148
# 1001
# Iterations passed: 152, time: 0.04261207580566406
# 152
# Iterations passed: 65, time: 0.02975940704345703
# 65
# Iterations passed: 106, time: 0.056760311126708984
# 106
# Iterations passed: 1001, time: 0.10824012756347656
# 1001
# Iterations passed: 51, time: 0.021683454513549805
# 51
# Iterations passed: 125, time: 0.08859992027282715
# 125
# Iterations passed: 1001, time: 0.10296225547790527
# 1001
# Iterations passed: 120, time: 0.053206682205200195
# 120
# Iterations passed: 105, time: 0.045964717864990234
# 105
# Iterations passed: 1001, time: 0.2613649368286133
# 1001
# Iterations passed: 1001, time: 0.12452983856201172
# 1001
# Iterations passed: 1001, time: 0.13945770263671875
# 1001
# Iterations passed: 113, time: 0.039545536041259766
# 113
# Iterations passed: 81, time: 0.01912236213684082
# 81
# Iterations passed: 1001, time: 0.23162317276000977
# 1001
# Iterations passed: 280, time: 0.08231711387634277
# 280
# Iterations passed: 66, time: 0.02563166618347168
# 66
# Iterations passed: 97, time: 0.026459932327270508
# 97
# Iterations passed: 1001, time: 0.08615255355834961
# 1001
# Iterations passed: 141, time: 0.04293394088745117
# 141
# Iterations passed: 1001, time: 0.10792922973632812
# 1001
# Iterations passed: 126, time: 0.02706766128540039
# 126
# Iterations passed: 19, time: 0.00426030158996582
# 19
# Iterations passed: 218, time: 0.05682492256164551
# 218
# Iterations passed: 1001, time: 0.06662654876708984
# 1001
# Iterations passed: 1001, time: 0.18235325813293457
# 1001
# Iterations passed: 92, time: 0.023160457611083984
# 92
# Iterations passed: 1001, time: 0.13318872451782227
# 1001
# Iterations passed: 142, time: 0.05325937271118164
# 142
# Iterations passed: 241, time: 0.08245539665222168
# 241
# Iterations passed: 1001, time: 0.10488176345825195
# 1001
# Iterations passed: 1001, time: 0.153151273727417
# 1001
# Iterations passed: 113, time: 0.03183412551879883
# 113
# Iterations passed: 75, time: 0.02248835563659668
# 75
# Iterations passed: 1001, time: 0.13712382316589355
# 1001
# Iterations passed: 220, time: 0.05809974670410156
# 220
# Iterations passed: 1001, time: 0.12101078033447266
# 1001
# Iterations passed: 114, time: 0.022479534149169922
# 114
# Iterations passed: 63, time: 0.01667332649230957
# 63
# Iterations passed: 175, time: 0.08189225196838379
# 175
# Iterations passed: 133, time: 0.025492191314697266
# 133
# Iterations passed: 54, time: 0.013957023620605469
# 54
# Iterations passed: 1001, time: 0.18547701835632324
# 1001
# Iterations passed: 1001, time: 0.07939457893371582
# 1001
# Iterations passed: 226, time: 0.06146955490112305
# 226
# Iterations passed: 65, time: 0.0175478458404541
# 65
# Iterations passed: 231, time: 0.07430219650268555
# 231
# Iterations passed: 92, time: 0.02201390266418457
# 92
# Iterations passed: 1001, time: 0.3480265140533447
# 1001
# Iterations passed: 100, time: 0.034414052963256836
# 100
# Iterations passed: 93, time: 0.02044081687927246
# 93
# Iterations passed: 1001, time: 0.15906453132629395
# 1001
# Iterations passed: 39, time: 0.0074498653411865234
# 39
# Iterations passed: 1001, time: 0.22328495979309082
# 1001
# Iterations passed: 1001, time: 0.09053516387939453
# 1001
# Iterations passed: 1001, time: 0.08643770217895508
# 1001
# Iterations passed: 36, time: 0.012228965759277344
# 36
# Iterations passed: 41, time: 0.011048316955566406
# 41
# Iterations passed: 63, time: 0.02227330207824707
# 63
# Iterations passed: 51, time: 0.021383285522460938
# 51
# Iterations passed: 93, time: 0.0391077995300293
# 93
# Iterations passed: 95, time: 0.04078483581542969
# 95
# Iterations passed: 1001, time: 0.12011957168579102
# 1001
# Iterations passed: 1001, time: 0.04359889030456543
# 1001
# Iterations passed: 80, time: 0.02420210838317871
# 80
# Iterations passed: 1001, time: 0.08334207534790039
# 1001
# Iterations passed: 48, time: 0.02560591697692871
# 48
# Iterations passed: 117, time: 0.06702613830566406
# 117
# Iterations passed: 1001, time: 0.15105605125427246
# 1001
# Iterations passed: 1001, time: 0.07733035087585449
# 1001
# Iterations passed: 1001, time: 0.30124378204345703
# 1001
# Iterations passed: 1001, time: 0.15323615074157715
# 1001
# Iterations passed: 1001, time: 0.18446826934814453
# 1001
# Iterations passed: 1001, time: 0.11591243743896484
# 1001
# Iterations passed: 1001, time: 0.14883971214294434
# 1001
# Iterations passed: 1001, time: 0.0762488842010498
# 1001
# Iterations passed: 1001, time: 0.12877750396728516
# 1001
# Iterations passed: 57, time: 0.028651952743530273
# 57
# Iterations passed: 102, time: 0.032822608947753906
# 102
# Iterations passed: 1001, time: 0.08702397346496582
# 1001
# Iterations passed: 122, time: 0.03032207489013672
# 122
# Iterations passed: 87, time: 0.018651485443115234
# 87
# Iterations passed: 1001, time: 0.18424725532531738
# 1001
# Iterations passed: 210, time: 0.043088436126708984
# 210
# Iterations passed: 1001, time: 0.23581838607788086
# 1001
# Iterations passed: 1001, time: 0.09952402114868164
# 1001
# Iterations passed: 1001, time: 0.08744025230407715
# 1001
# Iterations passed: 32, time: 0.010320901870727539
# 32
# Iterations passed: 1001, time: 0.19350194931030273
# 1001
# Iterations passed: 176, time: 0.04864501953125
# 176
# Iterations passed: 1001, time: 0.09531855583190918
# 1001
# Iterations passed: 146, time: 0.0280454158782959
# 146
# Iterations passed: 100, time: 0.024103403091430664
# 100
# Iterations passed: 1001, time: 0.13531112670898438
# 1001
# Iterations passed: 1001, time: 0.11762714385986328
# 1001
# Iterations passed: 1001, time: 0.08656048774719238
# 1001
# Iterations passed: 1001, time: 0.09208893775939941
# 1001
# Iterations passed: 252, time: 0.05666327476501465
# 252
# Iterations passed: 148, time: 0.038413047790527344
# 148
# Iterations passed: 130, time: 0.04027390480041504
# 130
# Iterations passed: 1001, time: 0.05882740020751953
# 1001
# Iterations passed: 53, time: 0.010278463363647461
# 53
# Iterations passed: 134, time: 0.023576974868774414
# 134
# Iterations passed: 102, time: 0.024079322814941406
# 102
# Iterations passed: 1001, time: 0.07998967170715332
# 1001
# Iterations passed: 142, time: 0.0251309871673584
# 142
# Iterations passed: 1001, time: 0.04807543754577637
# 1001
# Iterations passed: 1001, time: 0.0857851505279541
# 1001
# Iterations passed: 184, time: 0.032581329345703125
# 184
# Iterations passed: 1001, time: 0.06050729751586914
# 1001
# Iterations passed: 1001, time: 0.1480865478515625
# 1001
# Iterations passed: 1001, time: 0.20663666725158691
# 1001
# Iterations passed: 40, time: 0.014332056045532227
# 40
# Iterations passed: 118, time: 0.02240133285522461
# 118
# Iterations passed: 46, time: 0.013720035552978516
# 46
# Iterations passed: 1001, time: 0.14503145217895508
# 1001
# Iterations passed: 37, time: 0.011028051376342773
# 37
# Iterations passed: 1001, time: 0.14753437042236328
# 1001
# Iterations passed: 1001, time: 0.11429166793823242
# 1001
# Iterations passed: 290, time: 0.052780866622924805
# 290
# Iterations passed: 1001, time: 0.1632518768310547
# 1001
# Iterations passed: 1001, time: 0.06322813034057617
# 1001
# Iterations passed: 80, time: 0.0200655460357666
# 80
# Iterations passed: 1001, time: 0.07810592651367188
# 1001
# Iterations passed: 1001, time: 0.0543365478515625
# 1001
# Iterations passed: 1001, time: 0.1406538486480713
# 1001
# Iterations passed: 131, time: 0.02737569808959961
# 131
# Iterations passed: 1001, time: 0.04617643356323242
# 1001
# Iterations passed: 76, time: 0.01897406578063965
# 76
# Iterations passed: 1001, time: 0.11939144134521484
# 1001
# Iterations passed: 32, time: 0.008810997009277344
# 32
# Iterations passed: 1001, time: 0.3093886375427246
# 1001
# Iterations passed: 79, time: 0.015521526336669922
# 79
# Iterations passed: 169, time: 0.03320741653442383
# 169
# Iterations passed: 1001, time: 0.12448000907897949
# 1001
# Iterations passed: 191, time: 0.042632341384887695
# 191
# Iterations passed: 1001, time: 0.07865500450134277
# 1001
# Iterations passed: 128, time: 0.026584386825561523
# 128
# Iterations passed: 173, time: 0.04440784454345703
# 173
# Iterations passed: 105, time: 0.024890899658203125
# 105
# Iterations passed: 177, time: 0.05386972427368164
# 177
# Iterations passed: 1001, time: 0.11005711555480957
# 1001
# Iterations passed: 117, time: 0.030672073364257812
# 117
# Iterations passed: 1001, time: 0.1690807342529297
# 1001
# Iterations passed: 60, time: 0.015407085418701172
# 60
# Iterations passed: 1001, time: 0.0847616195678711
# 1001
# Iterations passed: 45, time: 0.013289451599121094
# 45
# Iterations passed: 1001, time: 0.07841968536376953
# 1001
# Iterations passed: 1001, time: 0.15468978881835938
# 1001
# Iterations passed: 36, time: 0.017652034759521484
# 36
# Iterations passed: 1001, time: 0.06006312370300293
# 1001
# Iterations passed: 1001, time: 0.03070235252380371
# 1001
# Iterations passed: 86, time: 0.0192108154296875
# 86
# Iterations passed: 83, time: 0.020572900772094727
# 83
# Iterations passed: 1001, time: 0.13155579566955566
# 1001
# Iterations passed: 99, time: 0.0263364315032959
# 99
# Iterations passed: 50, time: 0.016726970672607422
# 50
# Iterations passed: 1001, time: 0.10088491439819336
# 1001
# Iterations passed: 1001, time: 0.10570836067199707
# 1001
# Iterations passed: 1001, time: 0.20849323272705078
# 1001
# Iterations passed: 151, time: 0.05482220649719238
# 151
# Iterations passed: 1001, time: 0.12421417236328125
# 1001
# Iterations passed: 122, time: 0.03612875938415527
# 122
# Iterations passed: 147, time: 0.03491926193237305
# 147
# Iterations passed: 66, time: 0.015703678131103516
# 66
# Iterations passed: 1001, time: 0.20263266563415527
# 1001
# Iterations passed: 71, time: 0.017275094985961914
# 71
# Iterations passed: 1001, time: 0.07821941375732422
# 1001
# Iterations passed: 141, time: 0.044936418533325195
# 141
# Iterations passed: 1001, time: 0.07754158973693848
# 1001
# Iterations passed: 1001, time: 0.21060895919799805
# 1001
# Iterations passed: 39, time: 0.01025247573852539
# 39
# Iterations passed: 1001, time: 0.16602396965026855
# 1001
# Iterations passed: 40, time: 0.011518001556396484
# 40
# Iterations passed: 209, time: 0.049043893814086914
# 209
# Iterations passed: 113, time: 0.03908228874206543
# 113
# Iterations passed: 78, time: 0.042160987854003906
# 78
# Iterations passed: 1001, time: 0.11905956268310547
# 1001
# Iterations passed: 1001, time: 0.04555225372314453
# 1001
# Iterations passed: 1001, time: 0.0923001766204834
# 1001
# Iterations passed: 1001, time: 0.046485185623168945
# 1001
# Iterations passed: 1001, time: 0.10693120956420898
# 1001
# Iterations passed: 1001, time: 0.10075569152832031
# 1001
# Iterations passed: 190, time: 0.05328726768493652
# 190
# Iterations passed: 108, time: 0.02586054801940918
# 108
# Iterations passed: 1001, time: 0.13619518280029297
# 1001
# Iterations passed: 1001, time: 0.07600045204162598
# 1001
# Iterations passed: 78, time: 0.03846907615661621
# 78
# Iterations passed: 41, time: 0.01031184196472168
# 41
# Iterations passed: 109, time: 0.02176642417907715
# 109
# Iterations passed: 61, time: 0.014385461807250977
# 61
# Iterations passed: 1001, time: 0.056012868881225586
# 1001
# Iterations passed: 1001, time: 0.08563923835754395
# 1001
# Iterations passed: 23, time: 0.004960775375366211
# 23
# Iterations passed: 1001, time: 0.20060062408447266
# 1001
# Iterations passed: 188, time: 0.0394597053527832
# 188
# Iterations passed: 1001, time: 0.11444473266601562
# 1001
# Iterations passed: 60, time: 0.019732952117919922
# 60
# Iterations passed: 1001, time: 0.12137126922607422
# 1001
# Iterations passed: 1001, time: 0.061635494232177734
# 1001
# Iterations passed: 1001, time: 0.16904997825622559
# 1001
# Iterations passed: 1001, time: 0.10630154609680176
# 1001
# Iterations passed: 169, time: 0.04281020164489746
# 169
# Iterations passed: 1001, time: 0.13317203521728516
# 1001
# Iterations passed: 1001, time: 0.1087350845336914
# 1001
# Iterations passed: 40, time: 0.011782646179199219
# 40
# Iterations passed: 103, time: 0.02507781982421875
# 103
# Iterations passed: 49, time: 0.012141227722167969
# 49
# Iterations passed: 95, time: 0.017885923385620117
# 95
# Iterations passed: 1001, time: 0.12067294120788574
# 1001
# Iterations passed: 1001, time: 0.0886983871459961
# 1001
# Iterations passed: 1001, time: 0.09122633934020996
# 1001
# Iterations passed: 84, time: 0.015800952911376953
# 84
# Iterations passed: 110, time: 0.0271151065826416
# 110
# Iterations passed: 122, time: 0.030142545700073242
# 122
# Iterations passed: 65, time: 0.011248111724853516
# 65
# Iterations passed: 1001, time: 0.14684176445007324
# 1001
# Iterations passed: 1001, time: 0.08254718780517578
# 1001
# Iterations passed: 1001, time: 0.14191079139709473
# 1001
# Iterations passed: 1001, time: 0.18779468536376953
# 1001
# Iterations passed: 32, time: 0.00879216194152832
# 32
# Iterations passed: 86, time: 0.016403913497924805
# 86
# Iterations passed: 111, time: 0.02533411979675293
# 111
# Iterations passed: 1001, time: 0.05405545234680176
# 1001
# Iterations passed: 1001, time: 0.09982681274414062
# 1001
# Iterations passed: 1001, time: 0.11194825172424316
# 1001
# Iterations passed: 132, time: 0.031026363372802734
# 132
# Iterations passed: 137, time: 0.04090142250061035
# 137
# Iterations passed: 187, time: 0.054915666580200195
# 187
# Iterations passed: 50, time: 0.013324260711669922
# 50
# Iterations passed: 60, time: 0.011931896209716797
# 60
# Iterations passed: 93, time: 0.025789737701416016
# 93
# Iterations passed: 155, time: 0.02743220329284668
# 155
# Iterations passed: 63, time: 0.014866352081298828
# 63
# Iterations passed: 1001, time: 0.08931303024291992
# 1001
# Iterations passed: 54, time: 0.009709596633911133
# 54
# Iterations passed: 193, time: 0.04034781455993652
# 193
# Iterations passed: 1001, time: 0.17680597305297852
# 1001
# Iterations passed: 1001, time: 0.1020817756652832
# 1001
# Iterations passed: 65, time: 0.02461981773376465
# 65
# Iterations passed: 64, time: 0.022372007369995117
# 64
# Iterations passed: 56, time: 0.013252973556518555
# 56
# Iterations passed: 130, time: 0.032450199127197266
# 130
# Iterations passed: 78, time: 0.012215375900268555
# 78
# Iterations passed: 43, time: 0.013109207153320312
# 43
# Iterations passed: 1001, time: 0.14623689651489258
# 1001
# Iterations passed: 138, time: 0.03615164756774902
# 138
# Iterations passed: 1001, time: 0.10733652114868164
# 1001
# Iterations passed: 1001, time: 0.16912078857421875
# 1001
# Iterations passed: 111, time: 0.029044151306152344
# 111
# Iterations passed: 102, time: 0.02813577651977539
# 102
# Iterations passed: 179, time: 0.04423689842224121
# 179
# Iterations passed: 200, time: 0.050533294677734375
# 200
# Iterations passed: 85, time: 0.026807546615600586
# 85
# Iterations passed: 1001, time: 0.07678389549255371
# 1001
# Iterations passed: 1001, time: 0.1235964298248291
# 1001
# Iterations passed: 1001, time: 0.10499739646911621
# 1001
# Iterations passed: 1001, time: 0.10272622108459473
# 1001
# Iterations passed: 1001, time: 0.17074084281921387
# 1001
# Iterations passed: 210, time: 0.0366363525390625
# 210
# Iterations passed: 1001, time: 0.10738897323608398
# 1001
# Iterations passed: 137, time: 0.025188684463500977
# 137
# Iterations passed: 1001, time: 0.0610356330871582
# 1001
# Iterations passed: 89, time: 0.023260831832885742
# 89
# Iterations passed: 1001, time: 0.1522541046142578
# 1001
# Iterations passed: 140, time: 0.029773950576782227
# 140
# Iterations passed: 171, time: 0.05352783203125
# 171
# Iterations passed: 1001, time: 0.08210039138793945
# 1001
# Iterations passed: 61, time: 0.021244525909423828
# 61
# Iterations passed: 1001, time: 0.04877424240112305
# 1001
# Iterations passed: 1001, time: 0.14078068733215332
# 1001
# Iterations passed: 58, time: 0.010965824127197266
# 58
# Iterations passed: 1001, time: 0.09208106994628906
# 1001
# Iterations passed: 63, time: 0.01884293556213379
# 63
# Iterations passed: 166, time: 0.031998634338378906
# 166
# Iterations passed: 61, time: 0.01699376106262207
# 61
# Iterations passed: 50, time: 0.01459360122680664
# 50
# Iterations passed: 96, time: 0.014721155166625977
# 96
# Iterations passed: 1001, time: 0.10127711296081543
# 1001
# Iterations passed: 301, time: 0.06156015396118164
# 301
# Iterations passed: 1001, time: 0.11588501930236816
# 1001
# Iterations passed: 1001, time: 0.07364988327026367
# 1001
# Iterations passed: 134, time: 0.043393850326538086
# 134
# Iterations passed: 31, time: 0.006676912307739258
# 31
# Iterations passed: 57, time: 0.011405706405639648
# 57
# Iterations passed: 112, time: 0.020891904830932617
# 112
# Iterations passed: 1001, time: 0.0893259048461914
# 1001
# Iterations passed: 196, time: 0.04835629463195801
# 196
# Iterations passed: 1001, time: 0.1420736312866211
# 1001
# Iterations passed: 1001, time: 0.1459827423095703
# 1001
# Iterations passed: 1001, time: 0.09335470199584961
# 1001
# Iterations passed: 42, time: 0.014259815216064453
# 42
# Iterations passed: 210, time: 0.043913841247558594
# 210
# Iterations passed: 1001, time: 0.1596543788909912
# 1001
# Iterations passed: 31, time: 0.005453586578369141
# 31
# Iterations passed: 1001, time: 0.08278131484985352
# 1001
# Iterations passed: 1001, time: 0.19716811180114746
# 1001
# Iterations passed: 1001, time: 0.10093951225280762
# 1001
# Iterations passed: 1001, time: 0.12684416770935059
# 1001
# Iterations passed: 1001, time: 0.08776044845581055
# 1001
# Iterations passed: 26, time: 0.005060672760009766
# 26
# Iterations passed: 40, time: 0.014218568801879883
# 40
# Iterations passed: 1001, time: 0.1105794906616211
# 1001
# Iterations passed: 48, time: 0.013359308242797852
# 48
# Iterations passed: 1001, time: 0.10619330406188965
# 1001
# Iterations passed: 1001, time: 0.1956791877746582
# 1001
# Iterations passed: 1001, time: 0.08710050582885742
# 1001
# Iterations passed: 39, time: 0.00786900520324707
# 39
# Iterations passed: 45, time: 0.009381771087646484
# 45
# Iterations passed: 1001, time: 0.13997507095336914
# 1001
# Iterations passed: 1001, time: 0.08604145050048828
# 1001
# Iterations passed: 118, time: 0.025142192840576172
# 118
# Iterations passed: 1001, time: 0.0785665512084961
# 1001
# Iterations passed: 1001, time: 0.20987367630004883
# 1001
# Iterations passed: 119, time: 0.03529214859008789
# 119
# Iterations passed: 1001, time: 0.06688928604125977
# 1001
# Iterations passed: 1001, time: 0.06660914421081543
# 1001
# Iterations passed: 1001, time: 0.05144023895263672
# 1001
# Iterations passed: 1001, time: 0.08353304862976074
# 1001
# Iterations passed: 1001, time: 0.025376081466674805
# 1001
# Iterations passed: 1001, time: 0.14541006088256836
# 1001
# Iterations passed: 1001, time: 0.07669472694396973
# 1001
# Iterations passed: 1001, time: 0.09900808334350586
# 1001
# Iterations passed: 37, time: 0.008375167846679688
# 37
# Iterations passed: 1001, time: 0.12469792366027832
# 1001
# Iterations passed: 1001, time: 0.1445760726928711
# 1001
# Iterations passed: 27, time: 0.006987810134887695
# 27
# Iterations passed: 117, time: 0.03915548324584961
# 117
# Iterations passed: 1001, time: 0.10517334938049316
# 1001
# Iterations passed: 70, time: 0.016425371170043945
# 70
# Iterations passed: 218, time: 0.052286624908447266
# 218
# Iterations passed: 1001, time: 0.047823190689086914
# 1001
# Iterations passed: 140, time: 0.03268933296203613
# 140
# Iterations passed: 191, time: 0.041288137435913086
# 191
# Iterations passed: 1001, time: 0.04623723030090332
# 1001
# Iterations passed: 109, time: 0.020726680755615234
# 109
# Iterations passed: 70, time: 0.019084930419921875
# 70
# Iterations passed: 212, time: 0.04344892501831055
# 212
# Iterations passed: 102, time: 0.020868539810180664
# 102
# Iterations passed: 50, time: 0.009573221206665039
# 50
# Iterations passed: 327, time: 0.08361220359802246
# 327
# Iterations passed: 68, time: 0.012521505355834961
# 68
# Iterations passed: 172, time: 0.029270648956298828
# 172
# Iterations passed: 183, time: 0.02915787696838379
# 183
# Iterations passed: 64, time: 0.01508188247680664
# 64
# Iterations passed: 1001, time: 0.030749082565307617
# 1001
# Iterations passed: 1001, time: 0.07334232330322266
# 1001
# Iterations passed: 1001, time: 0.11447429656982422
# 1001
# Iterations passed: 1001, time: 0.1757946014404297
# 1001
# Iterations passed: 1001, time: 0.06928157806396484
# 1001
# Iterations passed: 128, time: 0.03167104721069336
# 128
# Iterations passed: 1001, time: 0.13822293281555176
# 1001
# Iterations passed: 1001, time: 0.08241605758666992
# 1001
# Iterations passed: 1001, time: 0.054419517517089844
# 1001
# Iterations passed: 85, time: 0.026509523391723633
# 85
# Iterations passed: 61, time: 0.01481008529663086
# 61
# Iterations passed: 19, time: 0.006055355072021484
# 19
# Iterations passed: 1001, time: 0.08235335350036621
# 1001
# Iterations passed: 1001, time: 0.08537030220031738
# 1001
# Iterations passed: 194, time: 0.04922771453857422
# 194
# Iterations passed: 209, time: 0.03904318809509277
# 209
# Iterations passed: 90, time: 0.024640321731567383
# 90
# Iterations passed: 1001, time: 0.10299348831176758
# 1001
# Iterations passed: 84, time: 0.02624678611755371
# 84
# Iterations passed: 1001, time: 0.1043848991394043
# 1001
# Iterations passed: 121, time: 0.034232139587402344
# 121
# Iterations passed: 1001, time: 0.06303548812866211
# 1001
# Iterations passed: 115, time: 0.025156736373901367
# 115
# Iterations passed: 1001, time: 0.06434321403503418
# 1001
# Iterations passed: 1001, time: 0.04006361961364746
# 1001
# Iterations passed: 1001, time: 0.13394379615783691
# 1001
# Iterations passed: 1001, time: 0.051535844802856445
# 1001
# Iterations passed: 74, time: 0.015696048736572266
# 74
# Iterations passed: 107, time: 0.025966882705688477
# 107
# Iterations passed: 84, time: 0.022044658660888672
# 84
# Iterations passed: 151, time: 0.030270814895629883
# 151
# Iterations passed: 1001, time: 0.08509969711303711
# 1001
# Iterations passed: 192, time: 0.04717063903808594
# 192
# Iterations passed: 1001, time: 0.08313703536987305
# 1001
# Iterations passed: 206, time: 0.040793418884277344
# 206
# Iterations passed: 111, time: 0.027944326400756836
# 111
# Iterations passed: 1001, time: 0.14936208724975586
# 1001
# Iterations passed: 73, time: 0.019318819046020508
# 73
# Iterations passed: 143, time: 0.041174888610839844
# 143
# Iterations passed: 1001, time: 0.06640958786010742
# 1001
# Iterations passed: 85, time: 0.026204586029052734
# 85
# Iterations passed: 137, time: 0.03399181365966797
# 137
# Iterations passed: 1001, time: 0.15692996978759766
# 1001
# Iterations passed: 1001, time: 0.12362194061279297
# 1001
# Iterations passed: 1001, time: 0.0865790843963623
# 1001
# Iterations passed: 65, time: 0.01942729949951172
# 65
# Iterations passed: 1001, time: 0.10626864433288574
# 1001
# Iterations passed: 30, time: 0.008788824081420898
# 30
# Iterations passed: 252, time: 0.055391550064086914
# 252
# Iterations passed: 21, time: 0.005586862564086914
# 21
# Iterations passed: 230, time: 0.04387497901916504
# 230
# Iterations passed: 1001, time: 0.08377599716186523
# 1001
# Iterations passed: 1001, time: 0.08792257308959961
# 1001
# Iterations passed: 1001, time: 0.07809114456176758
# 1001
# Iterations passed: 130, time: 0.035666704177856445
# 130
# Iterations passed: 1001, time: 0.09055233001708984
# 1001
# Iterations passed: 1001, time: 0.15184330940246582
# 1001
# Iterations passed: 1001, time: 0.09411978721618652
# 1001
# Iterations passed: 30, time: 0.006864309310913086
# 30
# Iterations passed: 1001, time: 0.0806267261505127
# 1001
# Iterations passed: 51, time: 0.009752273559570312
# 51
# Iterations passed: 87, time: 0.021132946014404297
# 87
# Iterations passed: 1001, time: 0.13040375709533691
# 1001
# Iterations passed: 1001, time: 0.12940168380737305
# 1001
# Iterations passed: 146, time: 0.02945089340209961
# 146
# Iterations passed: 71, time: 0.024442672729492188
# 71
# Iterations passed: 286, time: 0.0684969425201416
# 286
# Iterations passed: 1001, time: 0.10405659675598145
# 1001
# Iterations passed: 46, time: 0.009714841842651367
# 46
# Iterations passed: 1001, time: 0.11797285079956055
# 1001
# Iterations passed: 83, time: 0.026700973510742188
# 83
# Iterations passed: 182, time: 0.04390263557434082
# 182
# Iterations passed: 122, time: 0.02762293815612793
# 122
# Iterations passed: 147, time: 0.03148198127746582
# 147
# Iterations passed: 1001, time: 0.10082626342773438
# 1001
# Iterations passed: 204, time: 0.05643129348754883
# 204
# Iterations passed: 117, time: 0.02575516700744629
# 117
# Iterations passed: 1001, time: 0.1557776927947998
# 1001
# Iterations passed: 176, time: 0.052645206451416016
# 176
# Iterations passed: 114, time: 0.020130634307861328
# 114
# Iterations passed: 174, time: 0.034200429916381836
# 174
# Iterations passed: 110, time: 0.026131153106689453
# 110
# Iterations passed: 130, time: 0.03085947036743164
# 130
# Iterations passed: 85, time: 0.016840457916259766
# 85
# Iterations passed: 44, time: 0.01565265655517578
# 44
# Iterations passed: 1001, time: 0.10413908958435059
# 1001
# Iterations passed: 1001, time: 0.12759971618652344
# 1001
# Iterations passed: 1001, time: 0.08376455307006836
# 1001
# Iterations passed: 37, time: 0.010607004165649414
# 37
# Iterations passed: 50, time: 0.019379377365112305
# 50
# Iterations passed: 1001, time: 0.14706659317016602
# 1001
# Iterations passed: 1001, time: 0.1264357566833496
# 1001
# Iterations passed: 1001, time: 0.0995476245880127
# 1001
# Iterations passed: 1001, time: 0.08312225341796875
# 1001
# Iterations passed: 158, time: 0.02912139892578125
# 158
# Iterations passed: 1001, time: 0.11874914169311523
# 1001
# Iterations passed: 64, time: 0.01976323127746582
# 64
# Iterations passed: 1001, time: 0.11508703231811523
# 1001
# Iterations passed: 106, time: 0.020459651947021484
# 106
# Iterations passed: 1001, time: 0.03122091293334961
# 1001
# Iterations passed: 1001, time: 0.05999040603637695
# 1001
# Iterations passed: 1001, time: 0.12253355979919434
# 1001
# Iterations passed: 1001, time: 0.10125946998596191
# 1001
# Iterations passed: 36, time: 0.010727167129516602
# 36
# Iterations passed: 1001, time: 0.17766761779785156
# 1001
# Iterations passed: 1001, time: 0.11745834350585938
# 1001
# Iterations passed: 165, time: 0.0309908390045166
# 165
# Iterations passed: 1001, time: 0.11538243293762207
# 1001
# Iterations passed: 54, time: 0.012392520904541016
# 54
# Iterations passed: 92, time: 0.023339033126831055
# 92
# Iterations passed: 144, time: 0.03330278396606445
# 144
# Iterations passed: 76, time: 0.02449631690979004
# 76
# Iterations passed: 1001, time: 0.05984997749328613
# 1001
# Iterations passed: 1001, time: 0.1038215160369873
# 1001
# Iterations passed: 53, time: 0.015556573867797852
# 53
# Iterations passed: 31, time: 0.00820612907409668
# 31
# Iterations passed: 1001, time: 0.12982916831970215
# 1001
# Iterations passed: 1001, time: 0.15558457374572754
# 1001
# Iterations passed: 1001, time: 0.11123967170715332
# 1001
# Iterations passed: 1001, time: 0.08046698570251465
# 1001
# Iterations passed: 39, time: 0.013875007629394531
# 39
# Iterations passed: 147, time: 0.031356096267700195
# 147
# Iterations passed: 87, time: 0.026219606399536133
# 87
# Iterations passed: 1001, time: 0.11446142196655273
# 1001
# Iterations passed: 78, time: 0.016784191131591797
# 78
# Iterations passed: 182, time: 0.05705904960632324
# 182
# Iterations passed: 1001, time: 0.06852030754089355
# 1001
# Iterations passed: 110, time: 0.02590489387512207
# 110
# Iterations passed: 152, time: 0.030371427536010742
# 152
# Iterations passed: 200, time: 0.04358983039855957
# 200
# Iterations passed: 134, time: 0.03512144088745117
# 134
# Iterations passed: 1001, time: 0.0844106674194336
# 1001
# Iterations passed: 1001, time: 0.1019587516784668
# 1001
# Iterations passed: 69, time: 0.016715288162231445
# 69
# Iterations passed: 70, time: 0.019077062606811523
# 70
# Iterations passed: 82, time: 0.018143177032470703
# 82
# Iterations passed: 1001, time: 0.07777929306030273
# 1001
# Iterations passed: 1001, time: 0.12918543815612793
# 1001
# Iterations passed: 32, time: 0.010282039642333984
# 32
# Iterations passed: 1001, time: 0.09242463111877441
# 1001
# Iterations passed: 1001, time: 0.18715953826904297
# 1001
# Iterations passed: 95, time: 0.020966768264770508
# 95
# Iterations passed: 164, time: 0.028493165969848633
# 164
# Iterations passed: 43, time: 0.008277654647827148
# 43
# Iterations passed: 1001, time: 0.07545328140258789
# 1001
# Iterations passed: 1001, time: 0.08832168579101562
# 1001
# Iterations passed: 131, time: 0.03046584129333496
# 131
# Iterations passed: 40, time: 0.011077642440795898
# 40
# Iterations passed: 48, time: 0.01750659942626953
# 48
# Iterations passed: 103, time: 0.017464876174926758
# 103
# Iterations passed: 62, time: 0.015059947967529297
# 62
# Iterations passed: 1001, time: 0.08254313468933105
# 1001
# Iterations passed: 1001, time: 0.09472036361694336
# 1001
# Iterations passed: 1001, time: 0.08694291114807129
# 1001
# Iterations passed: 125, time: 0.03181600570678711
# 125
# Iterations passed: 77, time: 0.01937103271484375
# 77
# Iterations passed: 1001, time: 0.11862468719482422
# 1001
# Iterations passed: 144, time: 0.03245806694030762
# 144
# Iterations passed: 1001, time: 0.14500212669372559
# 1001
# Iterations passed: 1001, time: 0.09576654434204102
# 1001
# Iterations passed: 46, time: 0.011350154876708984
# 46
# Iterations passed: 105, time: 0.03734636306762695
# 105
# Iterations passed: 1001, time: 0.10437774658203125
# 1001
# Iterations passed: 45, time: 0.012815237045288086
# 45
# Iterations passed: 1001, time: 0.13207626342773438
# 1001
# Iterations passed: 56, time: 0.014298200607299805
# 56
# Iterations passed: 361, time: 0.07287216186523438
# 361
# Iterations passed: 136, time: 0.029947519302368164
# 136
# Iterations passed: 188, time: 0.042891502380371094
# 188
# Iterations passed: 202, time: 0.051377296447753906
# 202
# Iterations passed: 1001, time: 0.06122446060180664
# 1001
# Iterations passed: 1001, time: 0.10111165046691895
# 1001
# Iterations passed: 76, time: 0.016698122024536133
# 76
# Iterations passed: 1001, time: 0.08538532257080078
# 1001
# Iterations passed: 1001, time: 0.11746859550476074
# 1001
# Iterations passed: 99, time: 0.021778345108032227
# 99
# Iterations passed: 60, time: 0.01051473617553711
# 60
# Iterations passed: 1001, time: 0.14158916473388672
# 1001
# Iterations passed: 117, time: 0.028751373291015625
# 117
# Iterations passed: 245, time: 0.0599977970123291
# 245
# Iterations passed: 1001, time: 0.12034177780151367
# 1001
# Iterations passed: 1001, time: 0.15501046180725098
# 1001
# Iterations passed: 1001, time: 0.12692975997924805
# 1001
# Iterations passed: 33, time: 0.010323524475097656
# 33
# Iterations passed: 1001, time: 0.10144948959350586
# 1001
# Iterations passed: 254, time: 0.06900143623352051
# 254
# Iterations passed: 1001, time: 0.11882710456848145
# 1001
# Iterations passed: 1001, time: 0.11166024208068848
# 1001
# Iterations passed: 113, time: 0.028195858001708984
# 113
# Iterations passed: 1001, time: 0.1378014087677002
# 1001
# Iterations passed: 31, time: 0.006123542785644531
# 31
# Iterations passed: 59, time: 0.015331506729125977
# 59
# Iterations passed: 171, time: 0.04061722755432129
# 171
# Iterations passed: 1001, time: 0.07649111747741699
# 1001
# Iterations passed: 1001, time: 0.17744183540344238
# 1001
# Iterations passed: 130, time: 0.025847911834716797
# 130
# Iterations passed: 366, time: 0.09053611755371094
# 366
# Iterations passed: 1001, time: 0.06334757804870605
# 1001
# Iterations passed: 1001, time: 0.10136532783508301
# 1001
# Iterations passed: 1001, time: 0.14464998245239258
# 1001
# Iterations passed: 102, time: 0.03057074546813965
# 102
# Iterations passed: 163, time: 0.0273592472076416
# 163
# Iterations passed: 46, time: 0.01107335090637207
# 46
# Iterations passed: 61, time: 0.011228561401367188
# 61
# Iterations passed: 122, time: 0.029386043548583984
# 122
# Iterations passed: 199, time: 0.09256482124328613
# 199
# Iterations passed: 73, time: 0.025450944900512695
# 73
# Iterations passed: 105, time: 0.028900146484375
# 105
# Iterations passed: 61, time: 0.018178701400756836
# 61
# Iterations passed: 441, time: 0.09737849235534668
# 441
# Iterations passed: 94, time: 0.01798105239868164
# 94
# Iterations passed: 1001, time: 0.0780191421508789
# 1001
# Iterations passed: 164, time: 0.04150700569152832
# 164
# Iterations passed: 134, time: 0.027915477752685547
# 134
# Iterations passed: 230, time: 0.06457781791687012
# 230
# Iterations passed: 1001, time: 0.07716202735900879
# 1001
# Iterations passed: 1001, time: 0.0783076286315918
# 1001
# Iterations passed: 1001, time: 0.1266624927520752
# 1001
# Iterations passed: 172, time: 0.06663823127746582
# 172
# Iterations passed: 57, time: 0.019744873046875
# 57
# Iterations passed: 53, time: 0.012721776962280273
# 53
# Iterations passed: 55, time: 0.011557340621948242
# 55
# Iterations passed: 1001, time: 0.10376429557800293
# 1001
# Iterations passed: 1001, time: 0.09052252769470215
# 1001
# Iterations passed: 1001, time: 0.08325910568237305
# 1001
# Iterations passed: 152, time: 0.028533220291137695
# 152
# Iterations passed: 1001, time: 0.07837653160095215
# 1001
# Iterations passed: 45, time: 0.011464595794677734
# 45
# Iterations passed: 1001, time: 0.1282196044921875
# 1001
# Iterations passed: 1001, time: 0.12345623970031738
# 1001
# Iterations passed: 81, time: 0.020772933959960938
# 81
# Iterations passed: 47, time: 0.011507511138916016
# 47
# Iterations passed: 145, time: 0.04677462577819824
# 145
# Iterations passed: 1001, time: 0.10150337219238281
# 1001
# Iterations passed: 175, time: 0.03497123718261719
# 175
# Iterations passed: 84, time: 0.022801876068115234
# 84
# Iterations passed: 1001, time: 0.10033273696899414
# 1001
# Iterations passed: 1001, time: 0.07319235801696777
# 1001
# Iterations passed: 71, time: 0.015347719192504883
# 71
# Iterations passed: 174, time: 0.030206918716430664
# 174
# Iterations passed: 1001, time: 0.07035517692565918
# 1001
# Iterations passed: 59, time: 0.01347208023071289
# 59
# Iterations passed: 106, time: 0.02182316780090332
# 106
# Iterations passed: 1001, time: 0.08621382713317871
# 1001
# Iterations passed: 1001, time: 0.05846214294433594
# 1001
# Iterations passed: 1001, time: 0.09266495704650879
# 1001
# Iterations passed: 1001, time: 0.13958334922790527
# 1001
# Iterations passed: 1001, time: 0.1203317642211914
# 1001
# Iterations passed: 1001, time: 0.11303448677062988
# 1001
# Iterations passed: 78, time: 0.018421649932861328
# 78
# Iterations passed: 45, time: 0.016849517822265625
# 45
# Iterations passed: 1001, time: 0.11000394821166992
# 1001
# Iterations passed: 117, time: 0.027132511138916016
# 117
# Iterations passed: 41, time: 0.008716106414794922
# 41
# Iterations passed: 1001, time: 0.13025283813476562
# 1001
# Iterations passed: 1001, time: 0.06591224670410156
# 1001
# Iterations passed: 1001, time: 0.16646027565002441
# 1001
# Iterations passed: 1001, time: 0.11407923698425293
# 1001
# Iterations passed: 1001, time: 0.1307365894317627
# 1001
# Iterations passed: 122, time: 0.03799724578857422
# 122
# Iterations passed: 1001, time: 0.058287858963012695
# 1001
# Iterations passed: 1001, time: 0.19461464881896973
# 1001
# Iterations passed: 1001, time: 0.11896085739135742
# 1001
# Iterations passed: 70, time: 0.013054370880126953
# 70
# Iterations passed: 1001, time: 0.09606719017028809
# 1001
# Iterations passed: 1001, time: 0.09292411804199219
# 1001
# Iterations passed: 105, time: 0.022392988204956055
# 105
# Iterations passed: 96, time: 0.027337312698364258
# 96
# Iterations passed: 1001, time: 0.061254262924194336
# 1001
# Iterations passed: 1001, time: 0.09689211845397949
# 1001
# Iterations passed: 1001, time: 0.11857128143310547
# 1001
# Iterations passed: 77, time: 0.012592077255249023
# 77
# Iterations passed: 90, time: 0.02522730827331543
# 90
# Iterations passed: 1001, time: 0.0969538688659668
# 1001
# Iterations passed: 78, time: 0.02784895896911621
# 78
# Iterations passed: 99, time: 0.026915788650512695
# 99
# Iterations passed: 1001, time: 0.07666659355163574
# 1001
# Iterations passed: 1001, time: 0.13872647285461426
# 1001
# Iterations passed: 1001, time: 0.12190651893615723
# 1001
# Iterations passed: 108, time: 0.021585464477539062
# 108
# Iterations passed: 1001, time: 0.0773007869720459
# 1001
# Iterations passed: 1001, time: 0.055542945861816406
# 1001
# Iterations passed: 292, time: 0.06195807456970215
# 292
# Iterations passed: 1001, time: 0.0919351577758789
# 1001
# Iterations passed: 49, time: 0.013319730758666992
# 49
# Iterations passed: 1001, time: 0.078155517578125
# 1001
# Iterations passed: 110, time: 0.029126644134521484
# 110
# Iterations passed: 1001, time: 0.09193587303161621
# 1001
# Iterations passed: 1001, time: 0.08699607849121094
# 1001
# Iterations passed: 1001, time: 0.0950007438659668
# 1001
# Iterations passed: 43, time: 0.04222869873046875
# 43
# Iterations passed: 103, time: 0.11394762992858887
# 103
# Iterations passed: 75, time: 0.05782651901245117
# 75
# Iterations passed: 57, time: 0.02577805519104004
# 57
# Iterations passed: 1001, time: 0.22053861618041992
# 1001
# Iterations passed: 1001, time: 0.3367180824279785
# 1001
# Iterations passed: 1001, time: 0.07683920860290527
# 1001
# Iterations passed: 1001, time: 0.11490654945373535
# 1001
# Iterations passed: 1001, time: 0.20702266693115234
# 1001
# Iterations passed: 128, time: 0.03418707847595215
# 128
# Iterations passed: 1001, time: 0.06504201889038086
# 1001
# Iterations passed: 1001, time: 0.12251067161560059
# 1001
# Iterations passed: 1001, time: 0.05136227607727051
# 1001
# Iterations passed: 1001, time: 0.02190256118774414
# 1001
# Iterations passed: 111, time: 0.02339005470275879
# 111
# Iterations passed: 67, time: 0.01580953598022461
# 67
# Iterations passed: 1001, time: 0.07121825218200684
# 1001
# Iterations passed: 42, time: 0.010582208633422852
# 42
# Iterations passed: 205, time: 0.05398678779602051
# 205
# Iterations passed: 1001, time: 0.08011555671691895
# 1001
# Iterations passed: 1001, time: 0.14100408554077148
# 1001
# Iterations passed: 62, time: 0.01729726791381836
# 62
# Iterations passed: 1001, time: 0.12016582489013672
# 1001
# Iterations passed: 66, time: 0.010590553283691406
# 66
# Iterations passed: 1001, time: 0.0771322250366211
# 1001
# Iterations passed: 75, time: 0.021756649017333984
# 75
# Iterations passed: 215, time: 0.04534316062927246
# 215
# Iterations passed: 1001, time: 0.059914350509643555
# 1001
# Iterations passed: 69, time: 0.016156435012817383
# 69
# Iterations passed: 1001, time: 0.06952524185180664
# 1001
# Iterations passed: 1001, time: 0.07353711128234863
# 1001
# Iterations passed: 83, time: 0.024512052536010742
# 83
# Iterations passed: 1001, time: 0.11684632301330566
# 1001
# Iterations passed: 18, time: 0.00414586067199707
# 18
# Iterations passed: 1001, time: 0.0994868278503418
# 1001
# Iterations passed: 1001, time: 0.14402532577514648
# 1001
# Iterations passed: 1001, time: 0.1382756233215332
# 1001
# Iterations passed: 1001, time: 0.11338114738464355
# 1001
# Iterations passed: 56, time: 0.011116743087768555
# 56
# Iterations passed: 1001, time: 0.08715105056762695
# 1001
# Iterations passed: 145, time: 0.030779600143432617
# 145
# Iterations passed: 1001, time: 0.10384774208068848
# 1001
# Iterations passed: 312, time: 0.05682992935180664
# 312
# Iterations passed: 53, time: 0.014407873153686523
# 53
# Iterations passed: 88, time: 0.02625870704650879
# 88
# Iterations passed: 194, time: 0.057120323181152344
# 194
# Iterations passed: 48, time: 0.013962984085083008
# 48
# Iterations passed: 73, time: 0.01863384246826172
# 73
